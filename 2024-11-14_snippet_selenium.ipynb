# %% [markdown]
# # LOGIN

# %%
# # driver
# from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager
# from selenium import webdriver

# options = Options()
# options.add_experimental_option("detach", True)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])

# service = Service(excutable_path=ChromeDriverManager().install())
# driver = webdriver.Chrome(service=service, options=options)
# # driver.implicitly_wait(5)
# # driver.maximize_window()

# # login
# import time
# import random
# import pyperclip
# from selenium.webdriver.common.by import By
# from selenium.webdriver import ActionChains, Keys

# # browse
# driver.get("https://nid.naver.com/nidlogin.login?mode=form&url=https://www.naver.com/")

# # def
# def send_keys(obj, keys):
#     for key in keys:
#         time.sleep(random.randint(100, 900)/1000)

# # id
# id = driver.find_element(By.CSS_SELECTOR, "#id")
# id.click()
# #id.send_keys("hong")
# pyperclip.copy(conf.login_id)
# ActionChains(driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
# time.sleep(1)

# # pass
# pw = driver.find_element(By.CSS_SELECTOR, "#pw")
# pw.click()
# #pw.send_keys("gildong")
# pyperclip.copy(conf.login_pass)
# ActionChains(driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
# time.sleep(1)

# # login button
# login_btn = driver.find_element(By.CSS_SELECTOR, "#log\.login")
# login_btn.click()

# %% [markdown]
# # logging performance

# %%
# driver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver

options = Options()
# options.add_argument("--headless")  # 브라우저를 백그라운드에서 실행
# options.add_argument("--auto-open-devtools-for-tabs")  # DevTools를 자동으로 활성화
# options.add_experimental_option('excludeSwitches', ['enable-logging'])  # 콘솔로그 출력 안하게
# options.add_experimental_option("excludeSwitches", ["enable-automation"])  # 자동화 제어 메시지 제거
# options.add_experimental_option("useAutomationExtension", False)  # 자동화 확장기능 비활성화
# options.add_argument('--disable-blink-features=AutomationControlled')  # 자동화 탐지 회피
options.set_capability("goog:loggingPrefs", {"performance": "ALL"})  # performance 로그 활성화
service = Service(excutable_path=ChromeDriverManager().install())
#service = Service('chromedriver')  # chromedriver 경로 설정
driver = webdriver.Chrome(service=service, options=options)

### performance
import time
import json

# browse
driver.get("http://www.example.com")

# %%
# ### performance
# dic_method = {}
# for i in range(0, 6):
#     logs = driver.get_log('performance')
#     for entry in logs:

#         # check entry
#         # {'level': 'INFO', 'message': '{"message":{"method":"Network.responseReceivedExtraInfo","params":{"blockedCookies":[],"cookiePartitionKey":{"hasCrossSiteAncestor":false,"topLevelSite":"https://example.com"},"cookiePartitionKeyOpaque":false,"exemptedCookies":[],"headers":{"accept-ranges":"bytes","age":"439171","cache-control":"max-age=604800","content-encoding":"gzip","content-length":"648","content-type":"text/html","date":"Thu, 14 Nov 2024 07:13:50 GMT","etag":"\\"1088432560+gzip\\"","expires":"Thu, 21 Nov 2024 07:13:50 GMT","last-modified":"Sat, 12 Oct 2024 03:26:51 GMT","server":"ECAcc (sed/58F4)","vary":"Accept-Encoding","x-cache":"404-HIT"},"requestId":"72431.2","resourceIPAddressSpace":"Public","statusCode":404}},"webview":"56D07F832B177CA7C946EFC8CBC07C62"}', 'timestamp': 1731568430224}
#         for key in entry:
#             if key == 'level':
#                 None
#             elif key == 'message':
#                 None
#             elif key == 'timestamp':
#                 None
#             else:
#                 print("ENTRY", key)

#         # check message
#         # {"message":{"method":"Network.responseReceivedExtraInfo","params":{"blockedCookies":[],"cookiePartitionKey":{"hasCrossSiteAncestor":false,"topLevelSite":"https://example.com"},"cookiePartitionKeyOpaque":false,"exemptedCookies":[],"headers":{"accept-ranges":"bytes","age":"439171","cache-control":"max-age=604800","content-encoding":"gzip","content-length":"648","content-type":"text/html","date":"Thu, 14 Nov 2024 07:13:50 GMT","etag":"\\"1088432560+gzip\\"","expires":"Thu, 21 Nov 2024 07:13:50 GMT","last-modified":"Sat, 12 Oct 2024 03:26:51 GMT","server":"ECAcc (sed/58F4)","vary":"Accept-Encoding","x-cache":"404-HIT"},"requestId":"72431.2","resourceIPAddressSpace":"Public","statusCode":404}},"webview":"56D07F832B177CA7C946EFC8CBC07C62"}
#         message = json.loads(entry['message'])
#         for key in message:
#             if key == 'message':
#                 None
#             elif key == 'webview':
#                 None
#             else:
#                 print("message", key)
#         message = message['message']

#         # check method
#         # "method":"Network.responseReceivedExtraInfo"
#         method = message['method']
#         dic_method[method] = 0
#     print('---------------------------------------------')
#     time.sleep(3)

# %%
# ### method
# if 0:
#     """
#     Network.dataReceived
#     Network.loadingFailed
#     Network.loadingFinished
#     Network.policyUpdated
#     Network.requestServedFromCache
#     Network.requestWillBeSent
#     Network.requestWillBeSentExtraInfo
#     Network.resourceChangedPriority
#     Network.responseReceived
#     Network.responseReceivedExtraInfo
#     Page.domContentEventFired
#     Page.frameAttached
#     Page.frameClearedScheduledNavigation
#     Page.frameDetached
#     Page.frameNavigated
#     Page.frameRequestedNavigation
#     Page.frameResized
#     Page.frameScheduledNavigation
#     Page.frameStartedLoading
#     Page.frameStoppedLoading
#     Page.frameSubtreeWillBeDetached
#     Page.loadEventFired
#     """

# %%
# ### params: performance:entry['message']['message']['method'](==Network.responseReceived)['params']
# dic_type = {}
# for i in range(0, 6):
#     logs = driver.get_log('performance')
#     for entry in logs:
#         message = json.loads(entry['message'])['message']
#         if message['method'] != 'Network.responseReceived':
#             continue
#         for key in message['params']:
#             if key == 'frameId': # '7EB20DD87FA99BD8897E9FFE5BD7F1EF'
#                 None
#             elif key == 'hasExtraInfo': # True False
#                 None
#             elif key == 'loaderId': # '88CE6AD27AE647D904D90748CC9A291B"
#                 None
#             elif key == 'requestId': # 76229.42 # 1E11A60134D33A291538AAD2B0C6E130
#                 None
#             elif key == 'response': # xml
#                 None
#             elif key == 'timestamp': # 23373.400148
#                 None
#             elif key == 'type': # 'Document', 'Script', 'Stylesheet', 'Image', 'Fetch', 'XHR', 'Preflight', 'Other', 'Ping'
#                 dic_type[message['params'][key]] = 0
#                 None
#             else:
#                 print("message['params']", key)
#     print('---------------------------------------------')
#     time.sleep(3)

# %%
# ### params: performance:entry['message']['message']['method'](==Network.responseReceivedExtraInfo)['params']
# for i in range(0, 6):
#     logs = driver.get_log('performance')
#     for entry in logs:
#         message = json.loads(entry['message'])['message']
#         if message['method'] != 'Network.responseReceivedExtraInfo':
#             continue
#         for key in message['params']:
#             if key == 'blockedCookies':
#                 None
#             elif key == 'cookiePartitionKey':
#                 None
#             elif key == 'cookiePartitionKeyOpaque':
#                 None
#             elif key == 'exemptedCookies':
#                 None
#             elif key == 'headers':
#                 None
#             elif key == 'requestId':
#                 None
#             elif key == 'resourceIPAddressSpace':
#                 None
#             elif key == 'statusCode':
#                 None
#             else:
#                 print("message['params']", key)
#     print('---------------------------------------------')
#     time.sleep(3)

# %%
# ### response: performance:entry['message']['message']['method']['params']['response']
# for i in range(0, 6):
#     logs = driver.get_log('performance')
#     text = str(logs)
#     if text.find('Not') == -1:
#         time.sleep(3)
#         continue
#     print(text)
#     #     message = json.loads(entry['message'])['message']
#     #     if message['method'] != 'Network.responseReceived':
#     #         continue
#     #     print(message['params']['response'])
#     print('---------------------------------------------')
#     time.sleep(3)

# %%
### getResponseBody
dic_type = {}
for i in range(0, 6):
    logs = driver.get_log('performance')
    for entry in logs:
        message = json.loads(entry['message'])['message']
        if message['method'] != 'Network.responseReceived':
            continue
        params = message['params']
        response = message['params']['response']
        body_dict = driver.execute_cdp_cmd('Network.getResponseBody', {'requestId': params["requestId"]})
        print(body_dict['body'])

    print('---------------------------------------------')
    time.sleep(3)
